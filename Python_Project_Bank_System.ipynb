# %%
class BankSystem :

    bank_Counter=0
    def __init__(self):
        self.users=[]
        self.customers={}
        self.workers=[]
        bank.banks_Counter+=1

    
    def Create_New_Account(self,username,account_number,password,age,Nathional_Id,workStatus,intial_Balance=0):
        
        if account_number in self.customers:
            print("Account number already exists.")
        else:
            self.customers[account_number] = initial_balance
            print("Account created successfully.")
            
    
    def Deposit(self,account_number,amount):
        amount=float(input("Enter the balance to be deposit: "))
        if account_number in self.customers:
            self.balance = self.balance + amount
            print("The deposit is successful and the balance in the account if %f%" ,self.balance)
            
        else:
            print("Account number does not exist.")
   
    def Withdrawal(self,account_number):
        amount=float(input("Enter the amount to withdrawl: "))
        if account_number in self.customers:
            if(self.balance >= amount):
                self.balance = self.balance - amount
                print("The withdraw is successful and the current balance is %f%" ,self.balance)
            
            else:
                print("Insuficient Balance")
        else:
            print("Account number does not exist.")
            

    def LogIn(self,username,password):
        for i in self.users:
            if i["username"]==username and i["password"]==password:
                logined_in=True
                user=i
                print(f"Hello {username}")
                break

        if logined_in:
            while True:
                int_p=int(input("""      (1) check balance
                                          (2) Deposit
                                          (3) Withdrawl
                                          (4) cancel                   """))
            if int_p==1:
                print(user["balance"])
            elif int_p==2:
                self.Deposit(user["username"])
                dict={"user":user,"type": "Deposit"}
            elif int_p==3:
                self.Withdrawal(user["username"])
                dict={"user":user,"type": "withdraw"}
            else:
                return None
